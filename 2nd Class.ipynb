# %%
name = input('Enter name :')

print(name)
# Out:
# Enter name :Mashiur
# Mashiur

# %%
student1_name = 'Mashiur'
student1_age= 23
student1_weight= 80.20

# %%
#data type check
print(type(student1_name))
print(type(student1_age))
print(type(student1_weight))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
num1= int(input('Enter any number: '))
num2= int(input('Enter any number: '))

sum= num1+num2
print(sum)
# Out:
# Enter any number: 5
# Enter any number: 6
# 11
