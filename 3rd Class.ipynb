# %%
fruits= ['apple', 'orange', 'lemon', 'mango']

# %%
print(fruits)
# Out:
# ['apple', 'orange', 'lemon', 'mango']

# %%
type(fruits)
# Out:
# list

# %%
print(fruits[0])
# Out:
# apple

# %%
print(fruits[3])
# Out:
# mango

# %%
print(fruits [:3]) #3 er agea jotogula ache
# Out:
# ['apple', 'orange', 'lemon']

# %%
print(fruits[1:]) #1 er por sob
# Out:
# ['orange', 'lemon', 'mango']

# %%
for item in fruits:
  print(item)
# Out:
# apple
# orange
# lemon
# mango

# %%
for i in range(len(fruits)):
  print(i, fruits[i])
# Out:
# 0 apple
# 1 orange
# 2 lemon
# 3 mango

# %%
for index, item in enumerate(fruits): #using function
  print(index, item)
# Out:
# 0 apple
# 1 orange
# 2 lemon
# 3 mango

# %% [markdown]
# List complehension

# %%
number=[1,2,3,4,5,6,7,8,9]

square= [i*i for i in number if i%2==0]
print(square)
# Out:
# [4, 16, 36, 64]

# %%
tple=(3,4,5)
a,b,c=tple
print(a,b,c)
# Out:
# 3 4 5

# %% [markdown]
# Dictionary

# %%
person={
    'name':'mashiur',
    'age': 24
}
print (person['name'])
# Out:
# mashiur

# %%
for key, valye in person.items():
  print(key, value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-969517179.py in <cell line: 0>()
#       1 for key, valye in person.items():
# ----> 2   print(key, value)
#
# NameError: name 'value' is not defined
